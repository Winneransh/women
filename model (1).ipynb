# %%
# !pip install torch transformers datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 30.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# ...

# %%
import pandas as pd
import random

# Define normal dialogues related to safety
normal_dialogues = [
    "Hi my name is Suryansh","Hello how are you?","Hi what is your name?",
    "Thank you for your kindness","Hi","Hello",
    "Hi there!",
    "Hello!",
    "Hey!",
    "Hi, how’s it going?",
    "Hello, nice to see you!",
    "Hey, what’s up?",
    "Hi, how are you?",
    "Hello, how have you been?",
    "Hey, long time no see!",
    "Hi, how’s your day?",
    "Hello, how’s everything?",
    "Hey there, what’s new?",
    "Hi, good to see you!",
    "Hello, what’s going on?",
    "Hey, how are things?",
    "Hi, what’s up with you?",
    "Hello, how’s life treating you?",
    "Hey, how’s your day going?",
    "Hi there, how are you today?",
    "Hello, anything exciting happening?",
    "Hey, how have you been?",
    "Hi, what’s new with you?",
    "Hello, how’s your week been?",
    "Hey there, what’s up?",
    "Hi, good to catch up!",
    "Hello, how’s everything going?",
    "Hey, what’s new in your life?",
    "Hi, how’s it all going?",
    "Hello, what have you been up to?",
    "Hey, how’s your day so far?",
    "Hi there, how’s your week?",
    "Hello, how’s your day treating you?",
    "Hey, how’s everything with you?",
    "Hi, what’s happening?",
    "Hello, how’s your day been?",
    "Hey there, how are you doing?",
    "Hi, what’s up with you today?",
    "Hello, nice to see you again!",
    "Hey, how’s your week been?",
    "Hi there, anything new?",
    "Hello, how’s life going?",
    "Hey, what’s the latest?",
    "Hi, how’s everything on your end?",
    "Hello, how have you been?",
    "Hey there, how’s your day going?",
    "Hi, good to see you here!",
    "Hello, how’s your day shaping up?",
    "Hey, what’s new with you?",
    "Hi, how’s your day treating you?",
    "Hello, anything interesting happening?",
    "Hey, how’s your week going?",
    "Hi there, what’s up?",
    "Hello, nice to meet you!",
    "Hey, how’s everything going?",
    "Hi, what’s new in your world?",
    "Hello, how’s your day been so far?",
    "Hey there, how’s your day?",
    "Hi, anything new with you?",
    "Hello, what’s new in your life?",
    "Hey, how’s everything with you?",
    "Hi there, good to see you!",
    "Hello, how’s your day going so far?",
    "Hey, what’s new today?",
    "Hi, how’s your week been?",
    "Hello, anything exciting happening?",
    "Hey, how’s your day treating you?",
    "Hi there, how’s it going?",
    "Hello, what’s up with you?",
    "Hey, nice to see you!",
    "Hi, how have you been doing?",
    "Hello, how’s your day been?",
    "Hey, how’s life treating you?",
    "Hi there, what’s going on?",
    "Hello, good to see you!",
    "Hey, what’s new with you today?",
    "Hi, how’s your day shaping up?",
    "Hello, how’s everything with you?",
    "Hey there, how’s your week?",
    "Hi, what’s up with your day?",
    "Hello, anything new happening?",
    "Hey, how’s your day been so far?",
    "Hi, how’s your week treating you?",
    "Hello, what’s new in your world?",
    "Hey, how’s your day been?",
    "Hi there, how’s everything?",
    "Hello, what’s up with you today?",
    "Hey, good to see you again!",
    "Hi, how’s everything going?",
    "Hello, how’s your day shaping up?",
    "Hey, what’s new with you?",
    "Hi there, how have you been?",
    "Hello, nice to see you today!",
    "Hey, how’s your week been?",
    "Hi, what’s new in your life?",
    "Hello, how’s your day so far?",
    "Hey there, how’s everything going?",
    "Hi, what’s up with your week?",
    "Hello, how’s life treating you today?",
    "Hey, how’s everything with you?",
    "Hi there, what’s new today?",
    "Hello, good to see you again!",
    "Hey, how’s your day been?",
    "Hi, how’s everything on your end?",
    "Hello, how’s your week treating you?",
    "Hey, what’s new in your world?",
    "Hi there, how’s your day going?",
    "Hello, anything exciting happening today?",
    "Hey, how have you been?",
    "Hi, nice to catch up with you!",
    "Hello, how’s everything with you today?",
    "Hey there, what’s up?",
    "Hi, how’s your day been so far?",
    "Hello, what’s new with you today?",
    "Hey, good to see you here!",
    "Hi, how’s your week going?",
    "Hello, how’s your day shaping up?",
    "Hey, anything interesting happening today?",
    "Hi there, what’s new with you?",
    "Hello, nice to see you again!",
    "Hey, how’s everything going with you?",
    "Hi, how have you been?",
    "Hello, what’s up with your day?",
    "Hey, how’s your week treating you?",
    "Hi, good to see you!",
    "Hello, how’s your day been so far?",
    "Hey there, what’s new today?",
    "Hi, how’s your day shaping up?",
    "Hello, anything exciting happening?",
    "Hey, how’s everything with you today?",
    "Hi, nice to see you!",
    "Hello, how have you been?",
    "Hey, what’s new with you today?",
    "Hi there, how’s everything going?",
    "Hello, how’s your day been?",
    "Hey, how’s your week so far?",
    "Hi, what’s up with you today?",
    "Hello, good to see you again!",
    "Hey there, how’s your day shaping up?"




]

# Define anomalous dialogues related to safety concerns
anomalous_dialogues = [
     "I’m watching you from outside your house. If you don’t open the door, I’ll break in and hurt you.",
        "I’ve been following you. If you try to call the police or leave, I’ll make sure you’re in serious danger.",
        "I’m inside your car. If you report this or try to stop me, I’ll come after you.",
        "Your garage door was left open. I’m inside. If you try to stop me, you’ll face severe consequences.",
        "I’m at your front door. Open it now, or I’ll break it down and make sure you suffer.",
        "The back door was ajar. I’m inside your house. If you alert anyone, I’ll make things much worse.",
        "I’m hiding in your car. If you try to leave or call for help, I’ll make sure you’re hurt badly.",
        "I’m in your home. The door was unlocked. If you try to confront me, it’ll be disastrous for you.",
        "I’m watching from across the street. If you don’t come outside now, I’ll break in and cause serious harm.",
        "I’ve broken into your car. If you try to intervene or report this, I’ll make sure you regret it.",
        "I’m outside your window. If you don’t let me in, I’ll force my way in and make sure you’re harmed.",
        "I’m in your garage. You left it open. If you come near, you’ll face severe repercussions.",
        "I’m at your back door. It’s slightly open. If you try to stop me, I’ll break it down and make you regret it.",
        "I’m following you closely. If you try to call for help or run, I’ll make sure you’re in serious danger.",
        "I’ve broken into your home. If you try to interfere or call for help, it will end badly for you.",
        "I’m in your apartment building. If you try to escape or alert anyone, you’ll face severe consequences.",
        "I saw you leave your car unlocked. I’m taking your belongings. If you try to stop me, you’ll regret it.",
        "I’m at your door. Open it immediately, or I’ll break it down and make sure you’re harmed.",
        "I’m watching you from a distance. If you make any move to alert someone, I’ll make sure you face severe consequences.",
        "I’m in your car. You left it unlocked. If you try to stop me, you’ll face serious danger.",
        "I’m inside your home. The door was left open. If you try to interfere, I’ll make sure you regret it.",
        "I’m at your front door. If you don’t open it now, I’ll break it down and ensure you’re harmed.",
        "I’m hiding in your garage. You didn’t lock it properly. If you come near, you’ll be in grave danger.",
        "I’m outside your window. If you don’t let me in, I’ll break through and make sure you’re hurt.",
        "I’m inside your home. You didn’t secure it properly. If you try to stop me, it will be disastrous for you.",
     "I need help right now!",
    "Can someone please assist me?",
    "I’m in trouble—help!",
    "I’m scared—please help!",
    "I need urgent assistance!",
    "Please, I need help immediately!",
    "Help me, I’m in danger!",
    "I’m lost—can anyone help?",
    "Please, I can’t do this alone!",
    "Someone, please come quick!",
    "I’m hurt—help me!",
    "Help, I’m stranded!",
    "Please, I need someone right now!",
    "I’m in distress—help!",
    "I need help, I’m not safe!",
    "Can anyone hear me? I need help!",
    "I’m in an emergency—help!",
    "Help, I’m feeling overwhelmed!",
    "Please, I need assistance right away!",
    "I’m in a bad situation—help!",
    "Help! I’m stuck and can’t move!",
    "I need help, I’m panicking!",
    "Please, someone help me!",
    "I’m in trouble—someone help!",
    "Help! I’m in a vulnerable position!",
    "I’m struggling—please help!",
    "Please, I need emergency help!",
    "Help, I’m alone and scared!",
    "I need someone to come quickly!",
    "Help me, I’m in a precarious situation!",
    "I need urgent help—please assist!",
    "Help! I’m in a bind!",
    "I’m in a state of panic—help!",
    "Please, help me—I need assistance!",
    "Help, I’m in a dangerous place!",
    "I need help, I’m in trouble!",
    "Someone, I need help urgently!",
    "Help me, I’m feeling trapped!",
    "Please, I need someone to help now!",
    "I’m in an emergency situation—help!",
    "Help, I can’t manage alone!",
    "I need immediate help—please assist!",
    "Help! I’m stuck and need assistance!",
    "Please, come help me right away!",
    "I’m in distress—can you help?",
    "Help, I’m feeling overwhelmed and scared!",
    "Please, I need help right now!",
    "I’m in a crisis—please come quickly!",
    "Help! I’m lost and in trouble!",
    "I need urgent assistance—please help!",
    "Help me! I’m in a serious situation!",
    "Please help, I’m feeling desperate!",
    "Help, I’m in immediate need of assistance!",
    "I need help—please come fast!",
    "Help! I’m feeling unsafe and need help!",
    "I’m in trouble—please assist me now!",
    "Help, I’m in a compromising position!",
    "Please, I’m desperate for help!",
    "Help me, I’m in a challenging spot!",
    "I need urgent help—please come quickly!",
    "Help! I’m feeling anxious and trapped!",
    "I’m in a difficult situation—please help!",
    "Please help me, I’m feeling vulnerable!",
    "Help, I’m facing an emergency!",
    "I need immediate help—please assist me!",
    "Help, I’m overwhelmed and need assistance!",
    "I’m in a dire situation—please come help!",
    "Please, help me out—I need assistance!",
    "Help! I’m in a state of panic!",
    "I need help now—please come quickly!",
    "Help, I’m in a predicament and need help!",
    "I’m in urgent need of assistance—please help!",
    "Help! I’m in a frightening situation!",
    "Please assist me—I'm in trouble!",
    "Help, I’m facing a serious issue!",
    "I need immediate help—please come now!",
    "Help me, I’m feeling overwhelmed and lost!",
    "Please, I need urgent help right away!",
    "Help! I’m in a tight spot and need help!",
    "I’m in danger—please help me now!",
    "Help me, I’m in a vulnerable situation!",
    "Please, someone help me—I'm in trouble!",
    "Help, I need immediate assistance!",
    "I’m in an emergency—please assist me!",
    "Help! I’m feeling unsafe and need help!",
    "I need urgent help—please come quickly!",
     "Hey there, how about giving me a little show?",
    "I’d love to get to know you better—up close and personal.",
    "You’re looking hot today. How about a private chat?",
    "Mind if I get a closer look? You’re quite irresistible.",
    "How about you and I find somewhere more private?",
    "You look amazing—why don’t you come a bit closer?",
    "I’d love to see that smile in a more intimate setting.",
    "You’re making it hard to focus. Care to make it easier?",
    "Ever thought about having a little fun tonight?",
    "You look so good; I can’t take my eyes off you.",
    "Why don’t you come over here and let me get to know you better?",
    "You’re too stunning to ignore. How about a little private time?",
    "I can’t stop thinking about how good you’d look with me.",
    "How about we find somewhere alone and get to know each other?",
    "You’re driving me wild. Want to see what happens next?",
    "I’d love to see more of you—maybe in a more private setting?",
    "You’ve got a look that I can’t resist. How about a closer encounter?",
    "You’re so captivating; let’s make this more interesting.",
    "How about we go somewhere alone and have some fun?",
    "You look incredible—let’s find a place to explore that beauty.",
    "I can’t help but imagine how amazing you’d look with me.",
    "Why don’t we go somewhere private and get to know each other better?",
    "You’re looking so sexy. Care to give me some attention?",
    "Let’s go somewhere alone and see what happens.",
    "You’re really turning me on. How about we take this somewhere private?",
    "I’d love to get to know you in a more intimate setting.",
    "You’re too hot to be just a passing glance. How about a private chat?",
    "I can’t stop thinking about you. How about a more personal encounter?",
    "You’ve got a body that’s hard to ignore. How about we find somewhere alone?",
    "You’re looking incredible—let’s get away from here and have some fun.",
    "Why don’t we find a quiet place and see where this goes?",
    "You’re driving me crazy. Want to find out what else we can do?",
    "You’re too sexy to pass up. How about a little privacy?",
    "I’d love to get a closer look at you—maybe somewhere more private?",
    "You’re making it hard to concentrate. Let’s take this somewhere else.",
    "How about we get to know each other better—alone?",
    "You’re looking too good to ignore. Care for some private time?",
    "I’d love to see what’s underneath that outfit. Want to find a private spot?",
    "You’re looking so hot today. How about we find a place to have some fun?",
    "Why don’t we go somewhere alone and see where this goes?",
    "You’re making me think of some very interesting things. Care to explore?",
    "You’ve got a body that’s hard to resist. How about a little privacy?",
    "How about we find a private spot and get to know each other better?",
    "You’re looking so sexy. Want to get to know each other more intimately?",
    "I’d love to see you in a more private setting—what do you think?",
    "You’re too irresistible to just let slip by. How about a private chat?",
    "Why don’t we find somewhere alone and see what happens?",
    "You’re looking incredible—let’s get away from here and have some fun.",
    "I can’t help but imagine what we could do alone together.",
    "You’re making it hard to think. How about we find a private place?",
    "You’re looking so good I can’t wait to see you up close.",
    "How about a more intimate encounter? You won’t regret it.",
    "You’re too hot to be ignored. Want to take this somewhere private?",
    "Let’s get away from here and see how we can have some fun.",
    "You’re making me think of some very naughty things. Care to explore?",
    "How about a private chat where we can get to know each other better?",
    "You’re looking so sexy. Want to spend some private time with me?",
    "I’d love to get a closer look at you. Care to find a more private spot?",
    "You’re driving me wild. How about we get to know each other better alone?",
    "You look incredible—how about we take this somewhere more private?",
    "I can’t stop thinking about how amazing you’d look with me alone.",
    "You’re making me think of some very exciting things. Care to find out?",
    "How about a more personal encounter? You’ll love it.",
    "You’re too stunning to ignore. Let’s find a private place.",
    "I’d love to see more of you—maybe in a more intimate setting?",
    "You’re looking so hot today. How about a private rendezvous?",
    "Let’s get out of here and see where our chemistry takes us.",
    "You’ve got a body that’s hard to ignore. Want to find somewhere private?",
    "I can’t stop thinking about you. How about a more personal meeting?",
    "You’re looking too good to be just a glance. Care for some private time?",
    "How about we find a quiet place and see where this goes?",
    "You’re so captivating. Let’s explore that beauty somewhere alone.",
    "You’re driving me wild. How about a private chat and see where it goes?",
    "You look incredible. How about a more intimate encounter?",
    "I’d love to take this somewhere more personal. Interested?",
    "You’re too sexy to ignore. How about a little privacy?",
    "You’ve got an incredible allure. Let’s find somewhere alone.",
    "How about we get to know each other better in a more private setting?",
    "You’re making it hard to think. Want to take this somewhere else?",
    "You look amazing. Let’s find a place to explore that beauty.",
    "I can’t help but imagine how incredible you’d look with me.",
    "How about a private encounter where we can both have some fun?",
    "You’re looking too hot to be ignored. Let’s get to know each other better.",
    "I’d love to see what happens when we’re alone. Interested?",
    "You’re driving me wild. How about a private rendezvous?",
    "You’re too stunning to pass up. Want to find somewhere more private?",
    "How about a personal chat where we can get to know each other better?",
    "You’re looking so sexy today. Let’s find a place to have some fun.",
    "I’d love to explore that beauty of yours in a more intimate setting.",
    "You’re captivating. How about a private encounter to get to know each other?",
    "Let’s find a quiet spot and see where this chemistry takes us.",
    "You’re looking incredible—let’s have some fun in a more private place.",
    "You’re making me think of some very exciting things. Care to explore?",
    "How about we get to know each other better in a more personal setting?",
    "You’re too irresistible to ignore. How about a private chat?",
    "I’d love to see you up close and personal. How about a private spot?",
    "You’re looking so good. Let’s take this somewhere more intimate.",
    "How about we find somewhere alone and see where our chemistry leads?",
    "You’re captivating. Let’s explore that beauty in a more private setting.",
    "You’re making me think of some very thrilling things. Want to find out?",
    "I’d love to see how amazing you look up close. Care to join me somewhere private?",
    "You’re looking too hot to ignore. How about a private rendezvous?",
    "Let’s get away from here and see where this chemistry takes us.",
    "You’re too stunning to pass up. How about a personal meeting?",
    "How about a private chat where we can explore each other more?",
    "You’re looking incredible. Let’s find a quiet place and have some fun.",
    "You’ve got an allure that’s hard to resist. How about a private encounter?",
    "I’d love to see more of you—maybe in a more intimate setting.",
    "You’re making it hard to focus. How about we find somewhere alone?",
    "How about a private chat where we can get to know each other better?",
    "You’re looking so hot today. Let’s find a more private place to talk.",
    "I can’t help but imagine what we could do alone together. Care to find out?",
    "You’re too captivating to ignore. Let’s take this somewhere more personal.",
    "How about we get away from here and explore each other’s company?",
    "You look incredible. Let’s find a private spot and see where this goes.",
    "You’re making me think of some very exciting things. Care to explore?",
    "I’d love to get to know you better in a more intimate setting.",
    "You’re looking so sexy. How about we find a place to have some fun?",
    "You’re driving me wild. Let’s find somewhere alone and see where it goes.",
    "You’ve got a body that’s hard to resist. How about a private chat?",
    "I can’t stop thinking about how amazing you’d look with me. Interested?",
    "You’re looking incredible. How about a private rendezvous to get to know each other better?",
    "You’re too hot to ignore. Let’s explore that beauty in a more personal setting.",
    "How about we find somewhere alone and see where our chemistry leads us?",
    "You’re making me think of some very thrilling things. Care to join me?",
    "You’re captivating. Let’s take this to a more intimate setting.",
    "I’d love to see what we can do alone together. Interested?",
    "You look stunning today. How about we find a private place to chat?",
    "You’re too irresistible to ignore. Let’s explore each other’s company.",
    "How about a private encounter where we can get to know each other better?",
    "You’ve got an allure that’s hard to resist. How about a personal meeting?",
    "You’re looking so hot. Let’s find a place where we can have some fun.",
    "I’d love to see more of you in a more intimate setting. Care to join me?",
    "You’re making me think of some very exciting things. Want to explore?",
    "You’re too stunning to pass up. Let’s find somewhere private and see where this goes."




]

# Generate the dataset
data = []
for _ in range(len(normal_dialogues)):
    data.append({'dialogue': random.choice(normal_dialogues), 'label': 0})
for _ in range(len(anomalous_dialogues)):
    data.append({'dialogue': random.choice(anomalous_dialogues), 'label': 1})
random.shuffle(data)
# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv("women_safety.csv", index=False)


df = pd.read_csv("women_safety.csv")
df
# Out:
#                                               dialogue  label
# 0    You’re too stunning to pass up. Want to find s...      1
# 1    I can’t stop thinking about how amazing you’d ...      1
# 2                                      Hey, what’s up?      0
# 3                           Hey, how’s your day going?      0
# 4                   Hello, how’s your day been so far?      0
# ..                                                 ...    ...
# 385                               I’m in trouble—help!      1
# 386                           Hello, how’s everything?      0
# 387  I’d love to see you up close and personal. How...      1
# 388                   Hello, what’s new in your world?      0
# 389                           Hello, nice to meet you!      0
#
# [390 rows x 2 columns]

# %%
# !pip install nltk

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from transformers import RobertaForSequenceClassification, RobertaTokenizer, Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
from datasets import Dataset
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/women_safety.csv')

# Split the dataset
train_df, eval_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)

# Convert to Hugging Face dataset format
train_dataset = Dataset.from_pandas(train_df)
eval_dataset = Dataset.from_pandas(eval_df)

# Load the tokenizer
model_name = "roberta-base"
tokenizer = RobertaTokenizer.from_pretrained(model_name)

# Tokenize the data
def tokenize_function(examples):
    return tokenizer(examples['dialogue'], padding="max_length", truncation=True)

train_dataset = train_dataset.map(tokenize_function, batched=True)
eval_dataset = eval_dataset.map(tokenize_function, batched=True)

# Load the model
model = RobertaForSequenceClassification.from_pretrained(model_name, num_labels=2)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=5,
    weight_decay=0.01,
)

# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
)

# Train the model
trainer.train()

# Save the model
model.save_pretrained('./roberta_women_safety')
tokenizer.save_pretrained('./roberta_women_safety')

print("Model fine-tuned and saved to './roberta_women_safety'.")
# Out:
# ...
# Map:   0%|          | 0/78 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='195' max='195' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [195/195 02:51, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
# ...

# %%
import torch
from transformers import RobertaTokenizer, RobertaForSequenceClassification

# Define paths
model_path = 'roberta_finetuned_model'
tokenizer_path = 'roberta_tokenizer'

# Save the fine-tuned model and tokenizer
def save_model_and_tokenizer(model, tokenizer, model_path, tokenizer_path):
    model.save_pretrained(model_path)
    tokenizer.save_pretrained(tokenizer_path)
    print("Model and tokenizer saved.")

# Load the fine-tuned model and tokenizer
def load_model_and_tokenizer(model_path, tokenizer_path):
    model = RobertaForSequenceClassification.from_pretrained(model_path)
    tokenizer = RobertaTokenizer.from_pretrained(tokenizer_path)
    return model, tokenizer

# Save the fine-tuned model and tokenizer
save_model_and_tokenizer(model, tokenizer, model_path, tokenizer_path)

# Load the model and tokenizer
model, tokenizer = load_model_and_tokenizer(model_path, tokenizer_path)

# Define labels for the output
labels = {0: "Normal", 1: "Anomalous"}

# Function to predict anomaly
def predict_anomaly(dialogue, model, tokenizer):
    inputs = tokenizer(dialogue, return_tensors='pt', truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    predicted_class = torch.argmax(logits, dim=1).item()
    return labels[predicted_class]

# Example usage for user input
user_dialogue = input("Enter a dialogue: ")
predicted_label = predict_anomaly(user_dialogue, model, tokenizer)

# Print prediction result with proper labels
print(f"The predicted label for the input dialogue is: {predicted_label}")
# Out:
# Model and tokenizer saved.
# Enter a dialogue: Help me
# The predicted label for the input dialogue is: Normal

# %%
from transformers import RobertaForSequenceClassification, RobertaTokenizer, Trainer, TrainingArguments
model_path = '/content/roberta_women_safety'

model = RobertaForSequenceClassification.from_pretrained(model_path)
tokenizer = RobertaTokenizer.from_pretrained(model_path)

def predict_anomaly(dialogue, model, tokenizer):
    # Tokenize the input dialogue
    inputs = tokenizer(dialogue, return_tensors='pt', padding=True, truncation=True)

    # Move the model to evaluation mode and make predictions
    model.eval()
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predicted_class = torch.argmax(logits, dim=1).item()

    # Map predicted class to label
    label = 'normal' if predicted_class == 0 else 'anomalous'
    return label
new_dialogues = [

    "my name is suryansh"
]


# Predict and print results
for dialogue in new_dialogues:
    result = predict_anomaly(dialogue, model, tokenizer)

    print(f"Dialogue: '{dialogue}'\nPredicted Label: {result}\n")
# Out:
# Dialogue: 'my name is suryansh'
# Predicted Label: normal
